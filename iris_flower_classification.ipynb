# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Apaulgithub/oibsip_task1/main/Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=df)
plt.show()

# %%
sns.lineplot(data=df.drop(['Id', 'Species'], axis=1))
plt.show()

# %%
df.drop('Id', axis=1).plot.hist(subplots=True, layout=(2, 2), figsize=(10, 10), bins=20)
plt.show()

# %%
g = sns.FacetGrid(df, col='Species')
g = g.map(sns.kdeplot, 'SepalLengthCm')

# %%
sns.pairplot(df.drop('Id', axis=1))

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
X = df.drop(['Id', 'Species'], axis=1)
y = df.Species

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=5)

# %%
from sklearn.neighbors import KNeighborsClassifier
model_1 = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski')
model_1.fit(X_train, y_train)
model_1.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %%
from sklearn.linear_model import LogisticRegression
model_2 = LogisticRegression()
model_2.fit(X_train, y_train)
model_2.score(X_test, y_test)
# Out:
# 0.9833333333333333

# %%
from sklearn.svm import SVC
model_3 = SVC(kernel='rbf', random_state=0, gamma=.10, C=1.0)
model_3.fit(X_train, y_train)
model_3.score(X_test, y_test)
# Out:
# 0.9833333333333333

# %%
from sklearn.tree import DecisionTreeClassifier
model_4 = DecisionTreeClassifier()
model_4.fit(X_train, y_train)
model_4.score(X_test, y_test)
# Out:
# 0.9333333333333333
